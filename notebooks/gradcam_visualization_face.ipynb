# %%
import sys
import os
import random

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

if project_root not in sys.path:
    sys.path.append(project_root)

print("Project root added:", project_root)
# Out:
# Project root added: d:\Project v2

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

from core.gradcam import visualize_gradcam, generate_gradcam

# %%
IMG_PATH = r"D:\Project v2\datasets\face_dataset\test\fake\0AAZGFNCB1.jpg"

visualize_gradcam(IMG_PATH)
# Out:
# d:\Project v2\.venv\lib\site-packages\keras\src\models\functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input_layer_4']
# Received: inputs=Tensor(shape=(1, 224, 224, 3))
#   warnings.warn(msg)

# %%
sys.path.append(r"D:\Project v2")
from core.gradcam import visualize_gradcam

TEST_DIR = r"D:\Project v2\datasets\face_dataset\test"

all_images = []

for class_name in ["real", "fake"]:
    class_path = os.path.join(TEST_DIR, class_name)
    
    for img in os.listdir(class_path):
        if img.lower().endswith((".jpg", ".jpeg", ".png")):
            all_images.append(os.path.join(class_path, img))

random_images = random.sample(all_images, 2)

print("Randomly selected images:\n")

for img_path in random_images:
    print(img_path)
    visualize_gradcam(img_path)
# Out:
# Randomly selected images:
#
# D:\Project v2\datasets\face_dataset\test\real\01569.jpg
# D:\Project v2\datasets\face_dataset\test\real\03047.jpg
